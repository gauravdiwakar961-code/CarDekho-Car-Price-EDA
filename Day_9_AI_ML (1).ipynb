# %% [markdown]
# # AI & ML Road Map
#
# ## Python
# ## DAta Analysis
# ## Machine Learning
# ## Deep learning
# ## NLP. OPen AI
# ## Generative  AI
# ## Agentic AI
# ## AI Agents
# ## LM,LLM, VLLM(Chat gpt, Grok, Gemini)

# %% [markdown]
# # Data Analysis: Analyze data to get insights for future decision making
#
#
# ** How to do Data Analysis in python
# <br>
# **Ans**:
# <br>
#   **Modules**
#   <br>
#   **1. Numpy**
#       - To Create fast Array for large dataset
#   <br>
#   **2.Pandas**
#     - To Create DataFrame (Table)
#   <br>
#   **3.Matplotaib**
#       - To create chart andVisuals
#   <br>
#   **4.Seaborn**
#       - for Advance Chart and Visuals

# %%
# How to get data analysis?
# practice: Kaggle, IBM data, github, data,gov,
# data.gov.in,worldbankdataset

# %% [markdown]
#  # Project:
#  EDA on car dekho.com dataset

# %% [markdown]
# # step 1: Load importent modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import time
import os  # Operating System
import warnings
warnings.filterwarnings('ignore')
print("All Module Loaded Successfully!!")
# Out:
# All Module Loaded Successfully!!

# %% [markdown]
# # Step 2: Load Dataset from Kaggle

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("manishkr1754/cardekho-used-car-data")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'cardekho-used-car-data' dataset.
# Path to dataset files: /kaggle/input/cardekho-used-car-data

# %%
file_name = os.listdir(path)[0]
file_path = path +'/' +file_name
print(file_path)
# Out:
# /kaggle/input/cardekho-used-car-data/cardekho_dataset.csv

# %%
# .csv: comma,sepreated,values:Testual file

df = pd.read_csv(file_path)
print('Done')
# Out:
# Done

# %% [markdown]
# # Step 3:EDA (Exploratory data Analysis)

# %%
# Inshort: just Explore your data

# %%
#  How to view Table?
df
# Out:
#        Unnamed: 0         car_name     brand     model  vehicle_age  \
# 0               0      Maruti Alto    Maruti      Alto            9
# 1               1    Hyundai Grand   Hyundai     Grand            5
# 2               2      Hyundai i20   Hyundai       i20           11
# 3               3      Maruti Alto    Maruti      Alto            9
# 4               4    Ford Ecosport      Ford  Ecosport            6
# ...           ...              ...       ...       ...          ...
# 15406       19537      Hyundai i10   Hyundai       i10            9
# 15407       19540    Maruti Ertiga    Maruti    Ertiga            2
# 15408       19541      Skoda Rapid     Skoda     Rapid            6
# 15409       19542  Mahindra XUV500  Mahindra    XUV500            5
# 15410       19543       Honda City     Honda      City            2
#
#        km_driven seller_type fuel_type transmission_type  mileage  engine  \
# 0         120000  Individual    Petrol            Manual    19.70     796
# ...

# %%
#  How to view top 5 Data?
df.head()
# Out:
#    Unnamed: 0       car_name    brand     model  vehicle_age  km_driven  \
# 0           0    Maruti Alto   Maruti      Alto            9     120000
# 1           1  Hyundai Grand  Hyundai     Grand            5      20000
# 2           2    Hyundai i20  Hyundai       i20           11      60000
# 3           3    Maruti Alto   Maruti      Alto            9      37000
# 4           4  Ford Ecosport     Ford  Ecosport            6      30000
#
#   seller_type fuel_type transmission_type  mileage  engine  max_power  seats  \
# 0  Individual    Petrol            Manual    19.70     796      46.30      5
# 1  Individual    Petrol            Manual    18.90    1197      82.00      5
# 2  Individual    Petrol            Manual    17.00    1197      80.00      5
# 3  Individual    Petrol            Manual    20.92     998      67.10      5
# 4      Dealer    Diesel            Manual    22.77    1498      98.59      5
#
#    selling_price
# 0         120000
# 1         550000
# ...

# %%
#  How to view bottom 5 Data?
df.tail(3)
# Out:
#        Unnamed: 0         car_name     brand   model  vehicle_age  km_driven  \
# 15408       19541      Skoda Rapid     Skoda   Rapid            6      67000
# 15409       19542  Mahindra XUV500  Mahindra  XUV500            5    3800000
# 15410       19543       Honda City     Honda    City            2      13000
#
#       seller_type fuel_type transmission_type  mileage  engine  max_power  \
# 15408      Dealer    Diesel            Manual    21.14    1498     103.52
# 15409      Dealer    Diesel            Manual    16.00    2179     140.00
# 15410      Dealer    Petrol         Automatic    18.00    1497     117.60
#
#        seats  selling_price
# 15408      5         425000
# 15409      7        1225000
# 15410      5        1200000

# %%
# How to view all column name?
df.columns
# Out:
# Index(['Unnamed: 0', 'car_name', 'brand', 'model', 'vehicle_age', 'km_driven',
#        'seller_type', 'fuel_type', 'transmission_type', 'mileage', 'engine',
#        'max_power', 'seats', 'selling_price'],
#       dtype='object')

# %%
#  How to Drop/rename un_wanted column?
df1 = df.drop('Unnamed: 0',axis = 1)
# axis = 1 : column drop
# axis =0: row drop
print('Done')
# Out:
# Done

# %%
# How to check no of row and column
df1.shape
# Out:
# (15411, 13)

# %%
 row , column = df1.shape

 print('Total Row=',row)
 print('Total column=',column)
# Out:
# Total Row= 15411
# Total column= 13

# %%
#  How to check some samples?
df1.sample(4)
# Out:
#               car_name     brand   model  vehicle_age  km_driven seller_type  \
# 11750    Hyundai Grand   Hyundai   Grand            4      46758      Dealer
# 14130            BMW 3       BMW       3            9      66000      Dealer
# 13072  Mahindra KUV100  Mahindra  KUV100            3      15000  Individual
# 14394      Maruti Alto    Maruti    Alto            6      16000      Dealer
#
#       fuel_type transmission_type  mileage  engine  max_power  seats  \
# 11750    Petrol         Automatic    18.90    1197      82.00      5
# 14130    Diesel         Automatic    16.07    1995     181.00      5
# 13072    Petrol            Manual    18.15    1198      82.00      5
# 14394    Petrol         Automatic    23.95     998      67.05      5
#
#        selling_price
# 11750         500000
# 14130         995000
# 13072         470000
# 14394         388000

# %%
#  How to check null data info
#  Null: Missing Data

df1.isna().sum()
#  Since all values are Zero, hence no null data
# Out:
# car_name             0
# brand                0
# model                0
# vehicle_age          0
# km_driven            0
# seller_type          0
# fuel_type            0
# transmission_type    0
# mileage              0
# engine               0
# max_power            0
# seats                0
# selling_price        0
# dtype: int64

# %%
#  How to show each column info?
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15411 entries, 0 to 15410
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   car_name           15411 non-null  object
#  1   brand              15411 non-null  object
#  2   model              15411 non-null  object
#  3   vehicle_age        15411 non-null  int64
#  4   km_driven          15411 non-null  int64
#  5   seller_type        15411 non-null  object
#  6   fuel_type          15411 non-null  object
#  7   transmission_type  15411 non-null  object
#  8   mileage            15411 non-null  float64
#  9   engine             15411 non-null  int64
#  10  max_power          15411 non-null  float64
#  11  seats              15411 non-null  int64
#  12  selling_price      15411 non-null  int64
# dtypes: float64(2), int64(5), object(6)
# memory usage: 1.5+ MB

# %%
#  HOw to find data stats
#  It will give numerical cols stats
df1.describe().round(2)
# Out:
#        vehicle_age   km_driven   mileage    engine  max_power     seats  \
# count     15411.00    15411.00  15411.00  15411.00   15411.00  15411.00
# mean          6.04    55616.48     19.70   1486.06     100.59      5.33
# std           3.01    51618.55      4.17    521.11      42.97      0.81
# min           0.00      100.00      4.00    793.00      38.40      0.00
# 25%           4.00    30000.00     17.00   1197.00      74.00      5.00
# 50%           6.00    50000.00     19.67   1248.00      88.50      5.00
# 75%           8.00    70000.00     22.70   1582.00     117.30      5.00
# max          29.00  3800000.00     33.54   6592.00     626.00      9.00
#
#        selling_price
# count       15411.00
# mean       774971.12
# std        894128.36
# min         40000.00
# 25%        385000.00
# 50%        556000.00
# 75%        825000.00
# max      39500000.00

# %%
#  Textural or categorical data describe
df1.describe(include= 'object')
# Out:
#            car_name   brand  model seller_type fuel_type transmission_type
# count         15411   15411  15411       15411     15411             15411
# unique          121      32    120           3         5                 2
# top     Hyundai i20  Maruti    i20      Dealer    Petrol            Manual
# freq            906    4992    906        9539      7643             12225

# %%
#  How to check correclation b/w numerical feature
df1.corr(numeric_only = True).round(2)
# Out:
#                vehicle_age  km_driven  mileage  engine  max_power  seats  \
# vehicle_age           1.00       0.33    -0.26    0.10       0.01   0.03
# km_driven             0.33       1.00    -0.11    0.19       0.04   0.19
# mileage              -0.26      -0.11     1.00   -0.63      -0.53  -0.44
# engine                0.10       0.19    -0.63    1.00       0.81   0.55
# max_power             0.01       0.04    -0.53    0.81       1.00   0.17
# seats                 0.03       0.19    -0.44    0.55       0.17   1.00
# selling_price        -0.24      -0.08    -0.31    0.59       0.75   0.12
#
#                selling_price
# vehicle_age            -0.24
# km_driven              -0.08
# mileage                -0.31
# engine                  0.59
# max_power               0.75
# seats                   0.12
# selling_price           1.00

# %%
# corr: -1 to +1
#  -1 Close: Negative
#  1 Close: Positive
# 0: no correlation

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Multivariate Analysis:
# . More than two columns analysis
# <br>
# . Three More Columns

# %%
sns.pairplot(data=df1, hue='brand',
             palette='magma')

plt.show()

# %%
pd.set_option('display.max_row',150)
df1.groupby(['brand','model']) ['selling_price'].agg(['min','max','mean']).round()
# Out:
#                                  min       max        mean
# brand         model
# Audi          A4              750000   4200000   1566747.0
#               A6              857000   4600000   2076875.0
#               A8             2200000   5500000   3291667.0
#               Q7             1000000   6800000   3037391.0
# BMW           3               550000   4500000   1786303.0
#               5               550000   5800000   2903847.0
#               6              1500000   6500000   5099333.0
#               7               465000   8500000   3782649.0
#               X1              700000   3650000   2064352.0
#               X3             1275000   6100000   2521522.0
#               X4             4950000   6500000   5570000.0
#               X5             1375000   8100000   4276320.0
#               Z4             3100000   8250000   4479000.0
# Bentley       Continental    5200000  14500000   9266667.0
# Datsun        GO              180000    650000    356753.0
# ...

# %% [markdown]
# FAQ's

# %%
# Q1>> Most Expensive car?

df1['selling_price'].max()
# Out:
# 39500000

# %%
#  Masking Techinque
df1[df1['selling_price'] == df1['selling_price'].max()]
# Out:
#                car_name    brand      model  vehicle_age  km_driven  \
# 3799  Ferrari GTC4Lusso  Ferrari  GTC4Lusso            2       3800
#
#      seller_type fuel_type transmission_type  mileage  engine  max_power  \
# 3799      Dealer    Petrol         Automatic      4.0    3855      601.0
#
#       seats  selling_price
# 3799      4       39500000

# %%
#  Q2>> Most Chepest car
#  Masking Techinque
df1[df1['selling_price'] == df1['selling_price'].min()]
# Out:
#             car_name   brand    model  vehicle_age  km_driven seller_type  \
# 7607  Maruti Wagon R  Maruti  Wagon R           21      80000  Individual
#
#      fuel_type transmission_type  mileage  engine  max_power  seats  \
# 7607    Petrol            Manual     18.9     998       67.1      5
#
#       selling_price
# 7607          40000

# %%
# Q3>> Give list cars based on given criteria

brand = 'Honda'
budgest = 60000
fuel_type = 'Petrol'

df1[((df1['selling_price'] <= budgest) &
(df1['brand'] == brand) &
(df1['fuel_type'] == fuel_type))]
# Out:
#         car_name  brand model  vehicle_age  km_driven seller_type fuel_type  \
# 7361  Honda City  Honda  City           19     110000  Individual    Petrol
#
#      transmission_type  mileage  engine  max_power  seats  selling_price
# 7361            Manual     13.0    1493      100.0      5          50000

# %%
#  Q4>> list of top 10 Expensive Cars

df1.sort_values('selling_price', ascending=False).head(10)
# Out:
#                     car_name          brand        model  vehicle_age  \
# 3799       Ferrari GTC4Lusso        Ferrari    GTC4Lusso            2
# 10969      Rolls-Royce Ghost    Rolls-Royce        Ghost            4
# 1172     Bentley Continental        Bentley  Continental            9
# 9722   Mercedes-Benz S-Class  Mercedes-Benz      S-Class            3
# 9364         Porsche Cayenne        Porsche      Cayenne            4
# 10989  Mercedes-Benz S-Class  Mercedes-Benz      S-Class            2
# 1888   Mercedes-Benz S-Class  Mercedes-Benz      S-Class            5
# 11000       Land Rover Rover     Land Rover        Rover            4
# 8439                   BMW 7            BMW            7            3
# 3096                   BMW 7            BMW            7            3
#
#        km_driven seller_type fuel_type transmission_type  mileage  engine  \
# 3799        3800      Dealer    Petrol         Automatic     4.00    3855
# ...

# %%
#  Q5>> list of Top 10 chepest Cars
df1.sort_values('selling_price', ascending=True).head(10)
# Out:
#              car_name    brand    model  vehicle_age  km_driven seller_type  \
# 7607   Maruti Wagon R   Maruti  Wagon R           21      80000  Individual
# 13676     Maruti Alto   Maruti     Alto           17     110000  Individual
# 12298  Maruti Wagon R   Maruti  Wagon R           17      50000  Individual
# 7361       Honda City    Honda     City           19     110000  Individual
# 3787      Maruti Alto   Maruti     Alto           19     120000  Individual
# 7930   Maruti Wagon R   Maruti  Wagon R           15      45000      Dealer
# 2596      Maruti Alto   Maruti     Alto           29      22612      Dealer
# 9045   Hyundai Santro  Hyundai   Santro           14      50000  Individual
# 11190   Maruti Baleno   Maruti   Baleno           15      60500      Dealer
# 2966      Maruti Alto   Maruti     Alto           15      80000  Individual
#
#       fuel_type transmission_type  mileage  engine  max_power  seats  \
# ...

# %%
#  Q6>> All cars collection cost ?

cost = df1['selling_price'].sum()
print(cost)
# Out:
# 11943079875

# %% [markdown]
# # Final Takeaway and Outcomes
# **1. most cars vehicle age less than 15 years**<br>
# 2. **(0% cars have their km driven are less than 25k km)**<br>
# 3. **Most cars have their mileage range b/w 15  to 25 km(hr)**<br>
# 4.**98% cars have their engine cc less than 3000**<br>
# 5.**Use can afford upto 3.9 cr for super cars,but mostly below than 25 lakhs**<br>
# 6. **Include some more brands for better diversity**<br>
# 7.**mostly cars belongs to Mannual, consider some semi automatic or fully automatic**

# %%
# Missing Values

missing_values = df.isnull().sum()

print(missing_values)

plt.figure(figsize=(8,4))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title("Missing Values Heatmap")
plt.show()
# Out:
# Unnamed: 0           0
# car_name             0
# brand                0
# model                0
# vehicle_age          0
# km_driven            0
# seller_type          0
# fuel_type            0
# transmission_type    0
# mileage              0
# engine               0
# max_power            0
# seats                0
# selling_price        0
# dtype: int64

# %%
# Duplicate Values

print("Duplicate Rows :", df.duplicated().sum())

df = df.drop_duplicates()

print("After Removing :", df.duplicated().sum())
# Out:
# Duplicate Rows : 0
# After Removing : 0

# %%
# Dataset Information
print("Shape :", df.shape)

print("\nColumns")
print(df.columns)

print("\nData Types")
print(df.dtypes)

print("\nSummary Statistics")
print(df.describe())
# Out:
# Shape : (15411, 14)
#
# Columns
# Index(['Unnamed: 0', 'car_name', 'brand', 'model', 'vehicle_age', 'km_driven',
#        'seller_type', 'fuel_type', 'transmission_type', 'mileage', 'engine',
#        'max_power', 'seats', 'selling_price'],
#       dtype='object')
#
# Data Types
# Unnamed: 0             int64
# car_name              object
# brand                 object
# model                 object
# vehicle_age            int64
# km_driven              int64
# seller_type           object
# fuel_type             object
# transmission_type     object
# mileage              float64
# engine                 int64
# max_power            float64
# seats                  int64
# selling_price          int64
# dtype: object
#
# Summary Statistics
#          Unnamed: 0   vehicle_age     km_driven       mileage        engine  \
# count  15411.000000  15411.000000  1.541100e+04  15411.000000  15411.000000
# mean    9811.857699      6.036338  5.561648e+04     19.701151   1486.057751
# ...

# %%
# Numerical Columns Distribution
num_cols = df.select_dtypes(include=['int64','float64']).columns

for col in num_cols:
    plt.figure(figsize=(7,4))
    sns.histplot(df[col], kde=True)
    plt.title(f"Distribution of {col}")
    plt.show()

# %%
# Boxplot (Outliers)
for col in num_cols:
    plt.figure(figsize=(7,4))
    sns.boxplot(x=df[col])
    plt.title(f"Outliers in {col}")
    plt.show()

# %%
# Categorical Analysis
cat_cols = df.select_dtypes(include='object').columns

for col in cat_cols:
    plt.figure(figsize=(8,4))
    sns.countplot(data=df, x=col)
    plt.xticks(rotation=45)
    plt.title(f"Count Plot of {col}")
    plt.show()

# %%
# Correlation Heatmap
plt.figure(figsize=(10,7))

sns.heatmap(df.corr(numeric_only=True),
            annot=True,
            cmap='coolwarm')

plt.title("Correlation Heatmap")
plt.show()

# %%
# Pair Plot
sns.pairplot(df.select_dtypes(include=['int64','float64']))
plt.show()

# %% [markdown]
# ### Insights
#
# 1. Most cars belong to the Petrol category.
# 2. Newer cars generally have higher selling prices.
# 3. Some features have a strong positive correlation with price.
# 4. A few numerical columns contain outliers.
# 5. The dataset has been cleaned by removing duplicate records.

# %% [markdown]
# ### Conclusion
#
# - Dataset was cleaned successfully.
# - Missing values and duplicates were checked.
# - Numerical and categorical variables were analyzed.
# - Correlation between features was identified.
# - Outliers were detected using boxplots.
# - This EDA provides useful insights for further predictive modeling.

# %%
# Project Developed by: GAURAV DIWAKAR
